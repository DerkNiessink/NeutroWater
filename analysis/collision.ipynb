# %%
import numpy as np
import matplotlib.pyplot as plt
import scienceplots
plt.style.use("science")
import pandas as pd

from neutrons.diffusing_neutrons import DiffusingNeutrons
# Out:
# /tmp/ipykernel_26197/2245671407.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
def plot_trajectories(positions: np.ndarray, radius: float = None, height: float = None):
    
    fig = plt.figure(figsize=(8, 8))
    ax = fig.add_subplot(111, projection='3d')
    
    if radius is not None and height is not None:
        ax.plot([-radius, -radius], [0, 0], [-height/2, height/2], c="k")
        ax.plot([0, 0], [radius, radius], [-height/2, height/2], c="k")

    for position in positions:
        x = [p[0] for p in position]
        y = [p[1] for p in position]
        z = [p[2] for p in position]
        ax.plot(x, y, z, c="k", linewidth=0.3, alpha=0.5)

    ax.plot(0, 0, 0, "o", c="r")
    ax.set_xlabel("$x(m)$", fontsize=16)
    ax.set_ylabel("$y(m)$", fontsize=16)
    ax.set_box_aspect(aspect=None, zoom=0.9)
    ax.set_zlabel("$z(m)$", fontsize=16)
    
    if radius is not None and height is not None:
        #ax.plot([0], [0], [-height/2], "o", c="r")
        #ax.plot([0], [0], [height/2], "o", c="r")  # Adjust the height of the center point
        #ax.plot([0, 0], [0, 0], [-height/2, height/2], c="r")  # Adjust the height of the center line
        ax.plot([0, 0], [-radius, -radius], [-height/2, height/2], c="k")
        ax.plot([radius, radius], [0, 0], [-height/2, height/2], c="k")
        u = np.linspace(0, 2 * np.pi, 100)
        v = np.linspace(0, height, 100)
        x = radius * np.outer(np.cos(u), np.ones_like(v))
        y = radius * np.outer(np.sin(u), np.ones_like(v))
        z = np.outer(np.ones_like(u), v) - height/2  # Adjust the height of the cylinder
        ax.plot_surface(x, y, z, color="C0", alpha=0.2)
    plt.show()

# %%
data = pd.read_csv("data/mean_free_path.csv")
mean_free_paths = list(data["lambda(m)"])
energies = list(data["Energy(eV)"])

# %%
nNeutrons = 100
initial_positions = [np.array([0, 0, 0]) for _ in range(nNeutrons)]
initial_energies = [10*10**6 for _ in range(nNeutrons)]

diffusing_neutrons = DiffusingNeutrons(mean_free_paths, energies, initial_positions, initial_energies, radius_tank=0.2, height_tank=0.5)
diffusing_neutrons.diffuse(nCollisions=2)

plot_trajectories(diffusing_neutrons.get_positions(), diffusing_neutrons.tank.radius, diffusing_neutrons.tank.height)
print(diffusing_neutrons.get_number_escaped())
# Out:
# 0

# %%
diffusing_neutrons.diffuse(nCollisions=30)
plot_trajectories(diffusing_neutrons.get_positions(), diffusing_neutrons.tank.radius, diffusing_neutrons.tank.height)
diffusing_neutrons.get_number_escaped()
# Out:
# 0

# %%
nNeutrons = 10000
initial_positions = [np.array([0, 0, 0]) for _ in range(nNeutrons)]
initial_energies = [20*10**6 for _ in range(nNeutrons)]

diffusing_neutrons = DiffusingNeutrons(mean_free_paths, energies, initial_positions, initial_energies, radius_tank=0.2, height_tank=0.5)
diffusing_neutrons.diffuse(nCollisions=50)

#plot_trajectories(diffusing_neutrons.get_positions(), diffusing_neutrons.tank.radius, diffusing_neutrons.tank.height)
diffusing_neutrons.get_number_escaped()
# Out:
# 1541

# %%
nNeutrons = 10000
initial_positions = [np.array([0, 0, 0]) for _ in range(nNeutrons)]
initial_energies = [20*10**6 for _ in range(nNeutrons)]

diffusing_neutrons = DiffusingNeutrons(mean_free_paths, energies, initial_positions, initial_energies, radius_tank=0.2, height_tank=0.5)
diffusing_neutrons.diffuse(nCollisions=50)
# Out:
#          7911605 function calls (7911604 primitive calls) in 10.217 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         6    0.000    0.000   10.259    1.710 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3517(run_code)
#         6    0.000    0.000   10.259    1.710 {built-in method builtins.exec}
#         1    0.455    0.455   10.202   10.202 /home/derk/Documents/neutrons/src/neutrons/diffusing_neutrons.py:61(diffuse)
#    431470    0.145    0.000    6.792    0.000 /home/derk/Documents/neutrons/src/neutrons/diffusing_neutrons.py:54(_mf_lookup)
#    431470    0.968    0.000    6.646    0.000 /home/derk/Documents/neutrons/src/neutrons/diffusing_neutrons.py:108(idx_of_closest)
#    874473    5.510    0.000    5.510    0.000 {built-in method numpy.asarray}
#    433003    0.496    0.000    1.864    0.000 /home/derk/Documents/neutrons/src/neutrons/tank.py:30(inside)
#    443003    0.831    0.000    1.379    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/numpy/linalg/linalg.py:2383(norm)
#    431470    0.730    0.000    0.762    0.000 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:15(travel)
#    433003    0.254    0.000    0.254    0.000 {method 'dot' of 'numpy.ndarray' objects}
#    431470    0.201    0.000    0.201    0.000 {method 'argmin' of 'numpy.ndarray' objects}
#     10000    0.040    0.000    0.175    0.000 /home/derk/Documents/neutrons/src/neutrons/diffusing_neutrons.py:42(_random_directions)
#    431470    0.130    0.000    0.154    0.000 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:22(collide)
#    433003    0.070    0.000    0.096    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/numpy/linalg/linalg.py:140(isComplexType)
#    433003    0.072    0.000    0.072    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#    876006    0.062    0.000    0.062    0.000 {built-in method builtins.issubclass}
#    862940    0.057    0.000    0.057    0.000 {method 'append' of 'list' objects}
#     10000    0.047    0.000    0.047    0.000 {method 'normal' of 'numpy.random.mtrand.RandomState' objects}
#     10000    0.044    0.000    0.044    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#    443003    0.041    0.000    0.041    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/numpy/linalg/linalg.py:2379(_norm_dispatcher)
#    431506    0.037    0.000    0.037    0.000 {built-in method builtins.abs}
#     10000    0.009    0.000    0.009    0.000 {method 'astype' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.008    0.008 /home/derk/Documents/neutrons/src/neutrons/diffusing_neutrons.py:11(__init__)
#         1    0.000    0.000    0.008    0.008 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:33(__init__)
#         1    0.000    0.000    0.008    0.008 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:46(_init_neutrons)
#         1    0.002    0.002    0.008    0.008 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:50(<listcomp>)
#         1    0.002    0.002    0.006    0.006 /tmp/ipykernel_26197/1949292078.py:7(<listcomp>)
#     10000    0.005    0.000    0.006    0.000 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:11(__init__)
#     10000    0.004    0.000    0.004    0.000 {built-in method numpy.array}
#     10000    0.002    0.000    0.002    0.000 {method 'conj' of 'numpy.ndarray' objects}
#     10112    0.002    0.000    0.002    0.000 {built-in method builtins.isinstance}
# 10002/10001    0.001    0.000    0.001    0.000 {built-in method builtins.len}
#         6    0.000    0.000    0.001    0.000 /usr/lib/python3.10/codeop.py:117(__call__)
#         6    0.001    0.000    0.001    0.000 {built-in method builtins.compile}
#       112    0.000    0.000    0.001    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:770(_clean_thread_parent_frames)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_26197/1949292078.py:8(<listcomp>)
#        56    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/ipykernel/ipkernel.py:785(<setcomp>)
#        56    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1478(enumerate)
#       448    0.000    0.000    0.000    0.000 /usr/lib/python3.10/threading.py:1145(ident)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         1    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/src/neutrons/tank.py:23(__post_init__)
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:279(helper)
#         6    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/traitlets/traitlets.py:676(__get__)
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:102(__init__)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:139(__exit__)
#         6    0.000    0.000    0.000    0.000 /usr/lib/python3.10/contextlib.py:130(__enter__)
#       224    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#         6    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/traitlets/traitlets.py:629(get)
#       112    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#        12    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/IPython/core/compilerop.py:180(extra_flags)
#         6    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3469(compare)
#        56    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:55(__iter__)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_26197/1949292078.py:1(<module>)
#         6    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/venv/lib/python3.10/site-packages/IPython/core/interactiveshell.py:1255(user_global_ns)
#        12    0.000    0.000    0.000    0.000 /usr/lib/python3.10/typing.py:1737(cast)
#         1    0.000    0.000    0.000    0.000 /home/derk/Documents/neutrons/src/neutrons/neutrons.py:61(__len__)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
